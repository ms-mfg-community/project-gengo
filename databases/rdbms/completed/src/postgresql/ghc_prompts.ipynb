# %%
# !pip install ipython-sql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# %load_ext sql

# %%
# !pip install psycopg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip uninstall psycopg2 -y
# Out:
# WARNING: Skipping psycopg2 as it is not installed.

# %%
# !pip install psycopg2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 1.2/1.2 MB 8.3 MB/s eta 0:00:00
# ...

# %%
# %sql postgresql://ztmadmin:Sumimasen@0738@pfs-sql-01/ghc_prompts
# Out:
# Traceback (most recent call last):
#   File "C:\Users\prestopa\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prestopa\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\engine\base.py", line 3302, in raw_connection
#     return self.pool.connect()
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prestopa\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prestopa\AppData\Roaming\Python\Python311\site-packages\sqlalchemy\pool\base.py", line 1263, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
